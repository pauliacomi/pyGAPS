# %% [markdown]
# # Initial enthalpy calculations and enthalpy modelling
#
# The enthalpy of adsorption represents the energy released as heat during the adsorption process as a function of loading. It can be obtained either indirectly, through the isosteric heat method, or directly, using adsoption microcalorimetry. pyGAPS contains methods to determine the initial head of adsorption as well as attempt to model the enthalpy curve as a function of different contributions.
#
# First, make sure the data is imported by running the import notebook.

# %%
# %run import.ipynb
# Out:
# Selected 0 samples
# Selected 23 adsorbates
# Selected 5 isotherms with nitrogen at 77K
# Selected 2 room temperature calorimetry isotherms
# Selected 2 isotherms for IAST calculation
# Selected 3 isotherms for isosteric heat calculation

# %% [markdown]
# ### Initial point method

# %% [markdown]
# The point method of determining heat of adsorption is the simplest method. It just returns the first measured point in the enthalpy curve.
#
# Depending on the data, the first point method may be representative of the actual value.

# %%
import matplotlib.pyplot as plt

# Initial point method
res = pygaps.initial_enthalpy_point(isotherms_calorimetry[0], 'enthalpy', verbose=True)
plt.show()

res = pygaps.initial_enthalpy_point(isotherms_calorimetry[1], 'enthalpy', verbose=True)
plt.show()
# Out:
# The initial enthalpy of adsorption is:
# 	E = 28.79
# The initial enthalpy of adsorption is:
# 	E = 34.73

# %% [markdown]
# ### Compound model method

# %% [markdown]
# This method attempts to model the enthalpy curve by the superposition of several contributions. It is slower, as it runs a constrained minimisation algorithm with several initial starting guesses, then selects the optimal one.

# %%
# Modelling method
res = pygaps.initial_enthalpy_comp(isotherms_calorimetry[0], 'enthalpy', verbose=True)
plt.show()

res = pygaps.initial_enthalpy_comp(isotherms_calorimetry[1], 'enthalpy', verbose=True)
plt.show()
# Out:
# Bounds:
# 	const = (19.849417219261177, 28.739823218120005)
# 	preexp = (0, 150) , exp = (0, inf) , exploc = (0, 0.5)
# 	prepowa = (0, 50) , powa = (1, 20)
# 	prepowr = (-50, 0) , powr = (1, 20)
#
#
# Minimizing routine number 1
# Initial guess:
# 	const = 28.7398232181
# 	preexp = 0.0 , exp = 0.0 , exploc = 0.0
# 	prepowa = 0.0 , powa = 1.0
# 	prepowr = 0.0 , powr = 1.0
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.15346068920229522
#             Iterations: 75
#             Function evaluations: 753
#             Gradient evaluations: 75
#
#
# Minimizing routine number 2
# Initial guess:
# 	const = 28.7398232181
# 	preexp = 0.04814538698 , exp = 0.0 , exploc = 0.1
# 	prepowa = -8.55407132702 , powa = 1.0
# 	prepowr = -8.55407132702 , powr = 1.0
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.14458327058027373
#             Iterations: 102
#             Function evaluations: 1028
#             Gradient evaluations: 102
#
#
# Minimizing routine number 3
# Initial guess:
# 	const = 28.7398232181
# 	preexp = 0.07221808047 , exp = -10.0 , exploc = 0.1
# 	prepowa = 0.01 , powa = 3.0
# 	prepowr = 0.0 , powr = 1.0
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.14458327335986215
#             Iterations: 131
#             Function evaluations: 1330
#             Gradient evaluations: 131
#
#
# Minimizing routine number 4
# Initial guess:
# 	const = 28.7398232181
# 	preexp = 0.0 , exp = 0.0 , exploc = 0.1
# 	prepowa = 0.0 , powa = 3.0
# 	prepowr = -0.01 , powr = 3.0
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.15344687634103832
#             Iterations: 86
#             Function evaluations: 870
#             Gradient evaluations: 86
#
#
# Final best fit 0.15344687634103832
#
#
# The initial enthalpy of adsorption is:
# 	E = 29.69
# The constant contribution is
# 	19.85
# The exponential contribution is
# 	15.68 * exp(1.80E+00 * n) with the limit at 0.29
# The guest-guest attractive contribution is
# 	44 * n^3.5
# The guest-guest repulsive contribution is
# 	-50 * n^6.0
# Bounds:
# 	const = (23.797607891739087, 28.172649127709519)
# 	preexp = (0, 150) , exp = (0, inf) , exploc = (0, 0.5)
# 	prepowa = (0, 50) , powa = (1, 20)
# 	prepowr = (-50, 0) , powr = (1, 20)
#
#
# Minimizing routine number 1
# Initial guess:
# 	const = 28.1726491277
# 	preexp = 0.0 , exp = 0.0 , exploc = 0.0
# 	prepowa = 0.0 , powa = 1.0
# 	prepowr = 0.0 , powr = 1.0
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.09541800215310017
#             Iterations: 18
#             Function evaluations: 180
#             Gradient evaluations: 18
#
#
# Minimizing routine number 2
# Initial guess:
# 	const = 28.1726491277
# 	preexp = 6.55703632459 , exp = 0.0 , exploc = 0.1
# 	prepowa = 2.92773140339 , powa = 1.0
# 	prepowr = 2.92773140339 , powr = 1.0
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0072915914998274555
#             Iterations: 52
#             Function evaluations: 521
#             Gradient evaluations: 52
#
#
# Minimizing routine number 3
# Initial guess:
# 	const = 28.1726491277
# 	preexp = 9.83555448689 , exp = -10.0 , exploc = 0.1
# 	prepowa = 0.01 , powa = 3.0
# 	prepowr = 0.0 , powr = 1.0
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.007235460993735015
#             Iterations: 68
#             Function evaluations: 681
#             Gradient evaluations: 68
#
#
# Minimizing routine number 4
# Initial guess:
# 	const = 28.1726491277
# 	preexp = 0.0 , exp = 0.0 , exploc = 0.1
# 	prepowa = 0.0 , powa = 3.0
# 	prepowr = -0.01 , powr = 3.0
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.007334793821042706
#             Iterations: 62
#             Function evaluations: 621
#             Gradient evaluations: 62
#
#
# Final best fit 0.007334793821042706
#
#
# The initial enthalpy of adsorption is:
# 	E = 37.12
# The constant contribution is
# 	26.53
# The exponential contribution is
# 	21.18 * exp(1.23E+01 * n) with the limit at 0.00
# The guest-guest attractive contribution is
# 	50 * n^1.8e+01
# The guest-guest repulsive contribution is
# 	-46 * n^1.8e+01
